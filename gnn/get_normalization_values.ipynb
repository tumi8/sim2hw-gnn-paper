# %%
import pandas as pd
import numpy as np
import json
import re
from scipy.stats import gamma

# %%
NUM_TOPOS = 100

MAX_SAMPLES = 10000
SEED = 1234

LATENCY_FILES_DIR = '../../latency-files'
TOPO_CONFIG_DIR = '../../topo-configs'
GAMMA_PARAMS_FILE = '../../hvnet-gamma-parameters/gamma-params.json'

min_max_params = {}

# %%
# Flow rates and gamma params
with open(GAMMA_PARAMS_FILE) as f:
    gamma_params = json.load(f)

df = pd.DataFrame(gamma_params).T.reset_index()
df.columns = ['rate', 'shape', 'scale']
df['rate'] = df['rate'].astype(float)

df.rate = df.rate / 125  # scale to kbit/s

min_max_params['flow_rate'] = {
    'min': df['rate'].min(),
    'max': df['rate'].max(),
    'mean': df['rate'].mean(),
    'std': df['rate'].std()
}
min_max_params['flow_gamma_shape'] = {
    'min': df['shape'].min(),
    'max': df['shape'].max(),
    'mean': df['shape'].mean(),
    'std': df['shape'].std()
}
min_max_params['flow_gamma_scale'] = {
    'min': df['scale'].min(),
    'max': df['scale'].max(),
    'mean': df['scale'].mean(),
    'std': df['scale'].std()
}

# %%
# HVNet link rate
hvnet_link_rates = []
for i in range(NUM_TOPOS):
    with open(f'{TOPO_CONFIG_DIR}/nw-{i}.json') as f:
        topo_config = json.load(f)
    for link in topo_config["link"]:
        hvnet_link_rates.append(link["rate"])

hvnet_link_rates = np.array(hvnet_link_rates)
        
min_max_params['hvnet_link_rate'] = {
    'min': hvnet_link_rates.min(),
    'max': hvnet_link_rates.max(),
    'mean': hvnet_link_rates.mean(),
    'std': hvnet_link_rates.std()
}

# %%
# OMNeT++ link rate (hardcoded to 1000)
min_max_params['omnet_link_rate'] = {
    'min': 0.0,
    'max': 1000.0,
    'mean': 1000.0,
    'std': 0.0
}

# %%
# HVNet and OMNeT++ flow latency (mean, min, max, ...)
FEATURES = (
    ['mean', 'min', 'max', 'gamma_shape', 'gamma_scale']
    + [f'p{i}' for i in range(5, 96, 5)]
    + ['p99', 'p99.9', 'p99.99', 'p99.999', 'p99.9999']
)
    
def calc_feature(data, feature):
    quantile_pattern = r'p(\d+(\.\d+)?)'
    match = re.search(quantile_pattern, feature)
    if match:
        quantile = float(match.group(1)) / 100
        return data.quantile(quantile)

    if feature == 'mean':
        return data.mean()
    elif feature == 'min':
        return data.min()
    elif feature == 'max':
        return data.max()
    elif feature == 'gamma_shape':  # this covers both shape and scale
        if len(data) > MAX_SAMPLES:
            data = data.sample(n=MAX_SAMPLES, random_state=SEED)
        shape, _, scale = gamma.fit(data, floc=0)  # fix the loc param to 0
        return shape, scale
    else:
        raise ValueError(f'Invalid feature: {feature}')

latencies = {
    "hvnet": {},
    "omnet": {}
}
for feature in FEATURES:
    latencies['hvnet'][feature] = []
    latencies['omnet'][feature] = []

for i in range(NUM_TOPOS):
    try:
        print(f'loading config for topo {i}...', end='')
        with open(f'{TOPO_CONFIG_DIR}/nw-{i}.json') as f:
            topo_config = json.load(f)
            print('done.')
        print(f'loading HVNet latencies for topo {i}...', end='')
        df_latency_hvnet = pd.read_csv(f'{LATENCY_FILES_DIR}/latencies-hvnet/{i:02d}-latencies-hvnet-preprocessed.csv')
        print('done.')

        print(f'loading OMNeT++ latencies for topo {i}...', end='')
        df_latency_omnet = pd.read_csv(f'{LATENCY_FILES_DIR}/latencies-omnet/{i:02d}-latencies-omnet-preprocessed.csv')
        print('done.')

        for flow in topo_config['flow']:
            flow_num = int(flow['name'][1:])

            # HVNet
            flow_latency_hvnet = df_latency_hvnet[df_latency_hvnet.flow_num == flow_num].latency_us
            for feature in FEATURES:
                if feature == 'gamma_shape':
                    shape, scale = calc_feature(flow_latency_hvnet, feature)
                    latencies['hvnet']['gamma_shape'].append(shape)
                    latencies['hvnet']['gamma_scale'].append(scale)
                elif feature == 'gamma_scale':
                    continue
                else:
                    f_val = calc_feature(flow_latency_hvnet, feature)
                    latencies['hvnet'][feature].append(f_val)

            # OMNeT++
            flow_latency_omnet = df_latency_omnet[df_latency_omnet.flow_num == flow_num].latency_us
            for feature in FEATURES:
                if feature == 'gamma_shape':
                    shape, scale = calc_feature(flow_latency_omnet, feature)
                    latencies['omnet']['gamma_shape'].append(shape)
                    latencies['omnet']['gamma_scale'].append(scale)
                elif feature == 'gamma_scale':
                    continue
                else:
                    f_val = calc_feature(flow_latency_omnet, feature)
                    latencies['omnet'][feature].append(f_val)

    except FileNotFoundError:
        print(f'\nsome data for topo {i} is missing, skipping...')
        continue

for feature in FEATURES:
    latencies['hvnet'][feature] = np.array(latencies['hvnet'][feature])
    min_max_params[f'flow_latency_hvnet_{feature}'] = {
        'min': latencies['hvnet'][feature].min(),
        'max': latencies['hvnet'][feature].max(),
        'mean': latencies['hvnet'][feature].mean(),
        'std': latencies['hvnet'][feature].std()
    }
    latencies['omnet'][feature] = np.array(latencies['omnet'][feature])
    min_max_params[f'flow_latency_omnet_{feature}'] = {
        'min': latencies['omnet'][feature].min(),
        'max': latencies['omnet'][feature].max(),
        'mean': latencies['omnet'][feature].mean(),
        'std': latencies['omnet'][feature].std()
    }
# Out:
# loading config for topo 0...done.
# loading HVNet latencies for topo 0...done.
# loading OMNeT++ latencies for topo 0...done.
# loading config for topo 1...done.
# loading HVNet latencies for topo 1...done.
# loading OMNeT++ latencies for topo 1...done.
# loading config for topo 2...done.
# loading HVNet latencies for topo 2...done.
# loading OMNeT++ latencies for topo 2...done.
# loading config for topo 3...done.
# loading HVNet latencies for topo 3...done.
# loading OMNeT++ latencies for topo 3...done.
# loading config for topo 4...done.
# loading HVNet latencies for topo 4...done.
# loading OMNeT++ latencies for topo 4...done.
# loading config for topo 5...done.
# loading HVNet latencies for topo 5...done.
# loading OMNeT++ latencies for topo 5...done.
# loading config for topo 6...done.
# loading HVNet latencies for topo 6...done.
# loading OMNeT++ latencies for topo 6...done.
# loading config for topo 7...done.
# loading HVNet latencies for topo 7...done.
# loading OMNeT++ latencies for topo 7...done.
# loading config for topo 8...done.
# loading HVNet latencies for topo 8...done.
# loading OMNeT++ latencies for topo 8...done.
# loading config for topo 9...done.
# loading HVNet latencies for topo 9...done.
# loading OMNeT++ latencies for topo 9...done.
# loading config for topo 10...done.
# loading HVNet latencies for topo 10...done.
# loading OMNeT++ latencies for topo 10...done.
# loading config for topo 11...done.
# loading HVNet latencies for topo 11...done.
# loading OMNeT++ latencies for topo 11...done.
# loading config for topo 12...done.
# loading HVNet latencies for topo 12...done.
# loading OMNeT++ latencies for topo 12...done.
# loading config for topo 13...done.
# loading HVNet latencies for topo 13...done.
# loading OMNeT++ latencies for topo 13...done.
# loading config for topo 14...done.
# loading HVNet latencies for topo 14...done.
# loading OMNeT++ latencies for topo 14...done.
# loading config for topo 15...done.
# loading HVNet latencies for topo 15...done.
# loading OMNeT++ latencies for topo 15...done.
# loading config for topo 16...done.
# loading HVNet latencies for topo 16...done.
# loading OMNeT++ latencies for topo 16...done.
# loading config for topo 17...done.
# loading HVNet latencies for topo 17...done.
# loading OMNeT++ latencies for topo 17...done.
# loading config for topo 18...done.
# loading HVNet latencies for topo 18...done.
# loading OMNeT++ latencies for topo 18...done.
# loading config for topo 19...done.
# loading HVNet latencies for topo 19...done.
# loading OMNeT++ latencies for topo 19...done.
# loading config for topo 20...done.
# loading HVNet latencies for topo 20...done.
# loading OMNeT++ latencies for topo 20...done.
# loading config for topo 21...done.
# loading HVNet latencies for topo 21...done.
# loading OMNeT++ latencies for topo 21...done.
# loading config for topo 22...done.
# loading HVNet latencies for topo 22...done.
# loading OMNeT++ latencies for topo 22...done.
# loading config for topo 23...done.
# loading HVNet latencies for topo 23...done.
# loading OMNeT++ latencies for topo 23...done.
# loading config for topo 24...done.
# loading HVNet latencies for topo 24...done.
# loading OMNeT++ latencies for topo 24...done.
# loading config for topo 25...done.
# loading HVNet latencies for topo 25...done.
# loading OMNeT++ latencies for topo 25...done.
# loading config for topo 26...done.
# loading HVNet latencies for topo 26...done.
# loading OMNeT++ latencies for topo 26...done.
# loading config for topo 27...done.
# loading HVNet latencies for topo 27...done.
# loading OMNeT++ latencies for topo 27...done.
# loading config for topo 28...done.
# loading HVNet latencies for topo 28...done.
# loading OMNeT++ latencies for topo 28...done.
# loading config for topo 29...done.
# loading HVNet latencies for topo 29...done.
# loading OMNeT++ latencies for topo 29...done.
# loading config for topo 30...done.
# loading HVNet latencies for topo 30...done.
# loading OMNeT++ latencies for topo 30...done.
# loading config for topo 31...done.
# loading HVNet latencies for topo 31...done.
# loading OMNeT++ latencies for topo 31...done.
# loading config for topo 32...done.
# loading HVNet latencies for topo 32...done.
# loading OMNeT++ latencies for topo 32...done.
# loading config for topo 33...done.
# loading HVNet latencies for topo 33...
# some data for topo 33 is missing, skipping...
# loading config for topo 34...done.
# loading HVNet latencies for topo 34...done.
# loading OMNeT++ latencies for topo 34...done.
# loading config for topo 35...done.
# loading HVNet latencies for topo 35...done.
# loading OMNeT++ latencies for topo 35...done.
# loading config for topo 36...done.
# loading HVNet latencies for topo 36...done.
# loading OMNeT++ latencies for topo 36...done.
# loading config for topo 37...done.
# loading HVNet latencies for topo 37...done.
# loading OMNeT++ latencies for topo 37...done.
# loading config for topo 38...done.
# loading HVNet latencies for topo 38...done.
# loading OMNeT++ latencies for topo 38...done.
# loading config for topo 39...done.
# loading HVNet latencies for topo 39...done.
# loading OMNeT++ latencies for topo 39...done.
# loading config for topo 40...done.
# loading HVNet latencies for topo 40...done.
# loading OMNeT++ latencies for topo 40...done.
# loading config for topo 41...done.
# loading HVNet latencies for topo 41...done.
# loading OMNeT++ latencies for topo 41...done.
# loading config for topo 42...done.
# loading HVNet latencies for topo 42...done.
# loading OMNeT++ latencies for topo 42...done.
# loading config for topo 43...done.
# loading HVNet latencies for topo 43...done.
# loading OMNeT++ latencies for topo 43...done.
# loading config for topo 44...done.
# loading HVNet latencies for topo 44...done.
# loading OMNeT++ latencies for topo 44...done.
# loading config for topo 45...done.
# loading HVNet latencies for topo 45...done.
# loading OMNeT++ latencies for topo 45...done.
# loading config for topo 46...done.
# loading HVNet latencies for topo 46...done.
# loading OMNeT++ latencies for topo 46...done.
# loading config for topo 47...done.
# loading HVNet latencies for topo 47...done.
# loading OMNeT++ latencies for topo 47...done.
# loading config for topo 48...done.
# loading HVNet latencies for topo 48...done.
# loading OMNeT++ latencies for topo 48...done.
# loading config for topo 49...done.
# loading HVNet latencies for topo 49...done.
# loading OMNeT++ latencies for topo 49...done.
# loading config for topo 50...done.
# loading HVNet latencies for topo 50...done.
# loading OMNeT++ latencies for topo 50...done.
# loading config for topo 51...done.
# loading HVNet latencies for topo 51...done.
# loading OMNeT++ latencies for topo 51...done.
# loading config for topo 52...done.
# loading HVNet latencies for topo 52...done.
# loading OMNeT++ latencies for topo 52...done.
# loading config for topo 53...done.
# loading HVNet latencies for topo 53...done.
# loading OMNeT++ latencies for topo 53...done.
# loading config for topo 54...done.
# loading HVNet latencies for topo 54...done.
# loading OMNeT++ latencies for topo 54...done.
# loading config for topo 55...done.
# loading HVNet latencies for topo 55...done.
# loading OMNeT++ latencies for topo 55...done.
# loading config for topo 56...done.
# loading HVNet latencies for topo 56...done.
# loading OMNeT++ latencies for topo 56...done.
# loading config for topo 57...done.
# loading HVNet latencies for topo 57...done.
# loading OMNeT++ latencies for topo 57...done.
# loading config for topo 58...done.
# loading HVNet latencies for topo 58...done.
# loading OMNeT++ latencies for topo 58...done.
# loading config for topo 59...done.
# loading HVNet latencies for topo 59...done.
# loading OMNeT++ latencies for topo 59...done.
# loading config for topo 60...done.
# loading HVNet latencies for topo 60...done.
# loading OMNeT++ latencies for topo 60...done.
# loading config for topo 61...done.
# loading HVNet latencies for topo 61...done.
# loading OMNeT++ latencies for topo 61...done.
# loading config for topo 62...done.
# loading HVNet latencies for topo 62...done.
# loading OMNeT++ latencies for topo 62...done.
# loading config for topo 63...done.
# loading HVNet latencies for topo 63...done.
# loading OMNeT++ latencies for topo 63...done.
# loading config for topo 64...done.
# loading HVNet latencies for topo 64...done.
# loading OMNeT++ latencies for topo 64...done.
# loading config for topo 65...done.
# loading HVNet latencies for topo 65...done.
# loading OMNeT++ latencies for topo 65...done.
# loading config for topo 66...done.
# loading HVNet latencies for topo 66...done.
# loading OMNeT++ latencies for topo 66...done.
# loading config for topo 67...done.
# loading HVNet latencies for topo 67...done.
# loading OMNeT++ latencies for topo 67...done.
# loading config for topo 68...done.
# loading HVNet latencies for topo 68...done.
# loading OMNeT++ latencies for topo 68...done.
# loading config for topo 69...done.
# loading HVNet latencies for topo 69...done.
# loading OMNeT++ latencies for topo 69...done.
# loading config for topo 70...done.
# loading HVNet latencies for topo 70...done.
# loading OMNeT++ latencies for topo 70...done.
# loading config for topo 71...done.
# loading HVNet latencies for topo 71...done.
# loading OMNeT++ latencies for topo 71...done.
# loading config for topo 72...done.
# loading HVNet latencies for topo 72...done.
# loading OMNeT++ latencies for topo 72...done.
# loading config for topo 73...done.
# loading HVNet latencies for topo 73...done.
# loading OMNeT++ latencies for topo 73...done.
# loading config for topo 74...done.
# loading HVNet latencies for topo 74...done.
# loading OMNeT++ latencies for topo 74...done.
# loading config for topo 75...done.
# loading HVNet latencies for topo 75...done.
# loading OMNeT++ latencies for topo 75...done.
# loading config for topo 76...done.
# loading HVNet latencies for topo 76...done.
# loading OMNeT++ latencies for topo 76...done.
# loading config for topo 77...done.
# loading HVNet latencies for topo 77...done.
# loading OMNeT++ latencies for topo 77...done.
# loading config for topo 78...done.
# loading HVNet latencies for topo 78...
# some data for topo 78 is missing, skipping...
# loading config for topo 79...done.
# loading HVNet latencies for topo 79...
# some data for topo 79 is missing, skipping...
# loading config for topo 80...done.
# loading HVNet latencies for topo 80...done.
# loading OMNeT++ latencies for topo 80...done.
# loading config for topo 81...done.
# loading HVNet latencies for topo 81...done.
# loading OMNeT++ latencies for topo 81...done.
# loading config for topo 82...done.
# loading HVNet latencies for topo 82...done.
# loading OMNeT++ latencies for topo 82...done.
# loading config for topo 83...done.
# loading HVNet latencies for topo 83...done.
# loading OMNeT++ latencies for topo 83...done.
# loading config for topo 84...done.
# loading HVNet latencies for topo 84...done.
# loading OMNeT++ latencies for topo 84...done.
# loading config for topo 85...done.
# loading HVNet latencies for topo 85...done.
# loading OMNeT++ latencies for topo 85...done.
# loading config for topo 86...done.
# loading HVNet latencies for topo 86...done.
# loading OMNeT++ latencies for topo 86...done.
# loading config for topo 87...done.
# loading HVNet latencies for topo 87...done.
# loading OMNeT++ latencies for topo 87...done.
# loading config for topo 88...done.
# loading HVNet latencies for topo 88...done.
# loading OMNeT++ latencies for topo 88...done.
# loading config for topo 89...done.
# loading HVNet latencies for topo 89...done.
# loading OMNeT++ latencies for topo 89...done.
# loading config for topo 90...done.
# loading HVNet latencies for topo 90...done.
# loading OMNeT++ latencies for topo 90...done.
# loading config for topo 91...done.
# loading HVNet latencies for topo 91...done.
# loading OMNeT++ latencies for topo 91...done.
# loading config for topo 92...done.
# loading HVNet latencies for topo 92...done.
# loading OMNeT++ latencies for topo 92...done.
# loading config for topo 93...done.
# loading HVNet latencies for topo 93...done.
# loading OMNeT++ latencies for topo 93...done.
# loading config for topo 94...done.
# loading HVNet latencies for topo 94...done.
# loading OMNeT++ latencies for topo 94...done.
# loading config for topo 95...done.
# loading HVNet latencies for topo 95...done.
# loading OMNeT++ latencies for topo 95...done.
# loading config for topo 96...done.
# loading HVNet latencies for topo 96...done.
# loading OMNeT++ latencies for topo 96...done.
# loading config for topo 97...done.
# loading HVNet latencies for topo 97...done.
# loading OMNeT++ latencies for topo 97...done.
# loading config for topo 98...done.
# loading HVNet latencies for topo 98...done.
# loading OMNeT++ latencies for topo 98...done.
# loading config for topo 99...done.
# loading HVNet latencies for topo 99...done.
# loading OMNeT++ latencies for topo 99...done.

# %%
print(json.dumps(min_max_params, indent=4))
# Out:
# {
#     "flow_rate": {
#         "min": 1000.0,
#         "max": 831162.0,
#         "mean": 102175.78169542385,
#         "std": 112323.34995486778
#     },
#     "flow_gamma_shape": {
#         "min": 0.5325625213779135,
#         "max": 1.332074126203368,
#         "mean": 1.096132224296692,
#         "std": 0.08366515992073066
#     },
#     "flow_gamma_scale": {
#         "min": 3.016075680917091e-06,
#         "max": 0.003317930326235959,
#         "mean": 0.00018517353638414607,
#         "std": 0.00045421251453550443
#     },
#     "hvnet_link_rate": {
#         "min": 413.04347826086956,
#         "max": 1900.0,
#         "mean": 671.8528995756718,
#         "std": 195.02488880728907
#     },
#     "omnet_link_rate": {
#         "min": 0.0,
#         "max": 1000.0,
#         "mean": 1000.0,
#         "std": 0.0
#     },
#     "flow_latency_hvnet_mean": {
#         "min": 31.001229748590692,
#         "max": 14160.564920922061,
#         "mean": 205.20020575132045,
#         "std": 515.4280191835654
#     },
#     "flow_latency_omnet_mean": {
#         "min": 3.386831424575628,
#         "max": 3371.3255505160246,
#         "mean": 25.478652880378238,
#         "std": 242.8865446296346
#     },
#     "flow_latency_hvnet_min": {
#         "min": 12.95,
#         "max": 2105.737,
#         "mean": 47.45266725146199,
#         "std": 139.3754991922913
#     },
#     "flow_latency_omnet_min": {
#         "min": 3.386,
#         "max": 412.504526,
#         "mean": 6.886912530994152,
#         "std": 10.298895670522427
#     },
#     "flow_latency_hvnet_max": {
#         "min": 98.013,
#         "max": 1644617.362,
#         "mean": 11704.092897076025,
#         "std": 106094.62634583387
#     },
#     "flow_latency_omnet_max": {
#         "min": 5.726359,
#         "max": 3496.943725,
#         "mean": 46.1294269511696,
#         "std": 250.26675578818563
#     },
#     "flow_latency_hvnet_gamma_shape": {
#         "min": 0.1518510618757459,
#         "max": 1083.765214356513,
#         "mean": 15.915377454573028,
#         "std": 57.76734817199047
#     },
#     "flow_latency_omnet_gamma_shape": {
#         "min": 1.493742764860811,
#         "max": 16834.96520097552,
#         "mean": 257.8485399869026,
#         "std": 863.6769971469381
#     },
#     "flow_latency_hvnet_gamma_scale": {
#         "min": 0.8606651902084574,
#         "max": 51074.28755379639,
#         "mean": 78.97863770931232,
#         "std": 1355.9347833097886
#     },
#     "flow_latency_omnet_gamma_scale": {
#         "min": 0.00020116695380539064,
#         "max": 13.588618549520731,
#         "mean": 0.47556964309572347,
#         "std": 1.2611729048553246
#     },
#     "flow_latency_hvnet_p5": {
#         "min": 24.838,
#         "max": 2844.038,
#         "mean": 106.5860182748538,
#         "std": 250.25246141421326
#     },
#     "flow_latency_omnet_p5": {
#         "min": 3.386,
#         "max": 3220.7263602499997,
#         "mean": 23.501481892660827,
#         "std": 232.01038826368122
#     },
#     "flow_latency_hvnet_p10": {
#         "min": 25.55,
#         "max": 2887.825,
#         "mean": 118.26004064327485,
#         "std": 258.4861120352128
#     },
#     "flow_latency_omnet_p10": {
#         "min": 3.386,
#         "max": 3275.1906065000003,
#         "mean": 23.799052740292403,
#         "std": 235.97690609822845
#     },
#     "flow_latency_hvnet_p15": {
#         "min": 26.4,
#         "max": 2914.925,
#         "mean": 128.03804567251464,
#         "std": 265.77939288886773
#     },
#     "flow_latency_omnet_p15": {
#         "min": 3.386,
#         "max": 3305.5550602499998,
#         "mean": 23.9768282230848,
#         "std": 238.1990079625374
#     },
#     "flow_latency_hvnet_p20": {
#         "min": 26.725,
#         "max": 2935.325,
#         "mean": 138.68249175438598,
#         "std": 284.74054890316677
#     },
#     "flow_latency_omnet_p20": {
#         "min": 3.386,
#         "max": 3327.888423,
#         "mean": 24.119089961403517,
#         "std": 239.8039664668093
#     },
#     "flow_latency_hvnet_p25": {
#         "min": 27.15,
#         "max": 3067.92175,
#         "mean": 146.97718092105262,
#         "std": 299.5702308841741
#     },
#     "flow_latency_omnet_p25": {
#         "min": 3.386,
#         "max": 3345.02682775,
#         "mean": 24.24806220255849,
#         "std": 241.0524932221578
#     },
#     "flow_latency_hvnet_p30": {
#         "min": 27.7,
#         "max": 3133.6616,
#         "mean": 153.7587284210526,
#         "std": 304.5043693307437
#     },
#     "flow_latency_omnet_p30": {
#         "min": 3.386,
#         "max": 3359.1617185,
#         "mean": 24.37156903052632,
#         "std": 242.07541285932962
#     },
#     "flow_latency_hvnet_p35": {
#         "min": 28.263,
#         "max": 3171.85615,
#         "mean": 160.35210377192982,
#         "std": 308.9999609739882
#     },
#     "flow_latency_omnet_p35": {
#         "min": 3.386,
#         "max": 3371.07516725,
#         "mean": 24.49400990671053,
#         "std": 242.94084007756985
#     },
#     "flow_latency_hvnet_p40": {
#         "min": 28.587,
#         "max": 3208.042,
#         "mean": 166.9567419883041,
#         "std": 313.7760522927908
#     },
#     "flow_latency_omnet_p40": {
#         "min": 3.386,
#         "max": 3381.445706,
#         "mean": 24.622003823157904,
#         "std": 243.69004112725702
#     },
#     "flow_latency_hvnet_p45": {
#         "min": 28.8,
#         "max": 3247.1332500000003,
#         "mean": 173.65838133040936,
#         "std": 318.4605280977034
#     },
#     "flow_latency_omnet_p45": {
#         "min": 3.386,
#         "max": 3390.6832155,
#         "mean": 24.767420782002926,
#         "std": 244.35369285778225
#     },
#     "flow_latency_hvnet_p50": {
#         "min": 29.025,
#         "max": 3291.081,
#         "mean": 180.68565687134503,
#         "std": 323.42163417254204
#     },
#     "flow_latency_omnet_p50": {
#         "min": 3.386,
#         "max": 3398.972118,
#         "mean": 24.926435414327486,
#         "std": 244.94462283623074
#     },
#     "flow_latency_hvnet_p55": {
#         "min": 29.262,
#         "max": 3324.11755,
#         "mean": 189.05651809941523,
#         "std": 329.5299843366849
#     },
#     "flow_latency_omnet_p55": {
#         "min": 3.386,
#         "max": 3406.425665,
#         "mean": 25.10681166897661,
#         "std": 245.47682905667472
#     },
#     "flow_latency_hvnet_p60": {
#         "min": 29.5,
#         "max": 3352.3366,
#         "mean": 198.15758175438597,
#         "std": 336.78697677168725
#     },
#     "flow_latency_omnet_p60": {
#         "min": 3.386,
#         "max": 3413.230377,
#         "mean": 25.328063062631585,
#         "std": 245.96139201611473
#     },
#     "flow_latency_hvnet_p65": {
#         "min": 29.763,
#         "max": 3430.775,
#         "mean": 210.49786669590645,
#         "std": 357.158624714988
#     },
#     "flow_latency_omnet_p65": {
#         "min": 3.386,
#         "max": 3419.50485475,
#         "mean": 25.590455271900588,
#         "std": 246.40006330683772
#     },
#     "flow_latency_hvnet_p70": {
#         "min": 30.062,
#         "max": 3819.1,
#         "mean": 220.97378751461991,
#         "std": 370.89093343766274
#     },
#     "flow_latency_omnet_p70": {
#         "min": 3.386,
#         "max": 3425.2832049999997,
#         "mean": 25.90210294040936,
#         "std": 246.80373512950592
#     },
#     "flow_latency_hvnet_p75": {
#         "min": 30.412,
#         "max": 3860.449,
#         "mean": 234.92806242690057,
#         "std": 390.04155886407483
#     },
#     "flow_latency_omnet_p75": {
#         "min": 3.386,
#         "max": 3430.7042545000004,
#         "mean": 26.272016634429832,
#         "std": 247.17814471290873
#     },
#     "flow_latency_hvnet_p80": {
#         "min": 30.875,
#         "max": 3904.437,
#         "mean": 250.12219608187135,
#         "std": 417.82131867538385
#     },
#     "flow_latency_omnet_p80": {
#         "min": 3.386,
#         "max": 3435.7526860000003,
#         "mean": 26.71509779128655,
#         "std": 247.52242817629568
#     },
#     "flow_latency_hvnet_p85": {
#         "min": 31.7,
#         "max": 4229.0639,
#         "mean": 263.9491918274854,
#         "std": 435.6649570487105
#     },
#     "flow_latency_omnet_p85": {
#         "min": 3.386,
#         "max": 3440.48859765,
#         "mean": 27.27144498688597,
#         "std": 247.83671538690865
#     },
#     "flow_latency_hvnet_p90": {
#         "min": 33.562,
#         "max": 4355.1530999999995,
#         "mean": 280.58806719298246,
#         "std": 450.8986550724089
#     },
#     "flow_latency_omnet_p90": {
#         "min": 3.386,
#         "max": 3444.9939336,
#         "mean": 28.028537462953228,
#         "std": 248.1252012170677
#     },
#     "flow_latency_hvnet_p95": {
#         "min": 40.125,
#         "max": 4485.9166,
#         "mean": 304.93713410818714,
#         "std": 471.6984569587886
#     },
#     "flow_latency_omnet_p95": {
#         "min": 3.386,
#         "max": 3449.45503225,
#         "mean": 29.29764718950292,
#         "std": 248.37605080943598
#     },
#     "flow_latency_hvnet_p99": {
#         "min": 58.79116,
#         "max": 543682.4380000001,
#         "mean": 850.3847449619892,
#         "std": 15944.754280587655
#     },
#     "flow_latency_omnet_p99": {
#         "min": 3.386,
#         "max": 3457.1238335000003,
#         "mean": 32.17330318411404,
#         "std": 248.6431779548019
#     },
#     "flow_latency_hvnet_p99.9": {
#         "min": 74.01240000000071,
#         "max": 1260998.8344000033,
#         "mean": 1960.383269577812,
#         "std": 42065.0708329345
#     },
#     "flow_latency_omnet_p99.9": {
#         "min": 3.386,
#         "max": 3466.509921886001,
#         "mean": 36.3534001319154,
#         "std": 249.00368335076865
#     },
#     "flow_latency_hvnet_p99.99": {
#         "min": 93.96812819999994,
#         "max": 1337844.8655599903,
#         "mean": 4276.929442647965,
#         "std": 50985.42148227718
#     },
#     "flow_latency_omnet_p99.99": {
#         "min": 5.296854852599892,
#         "max": 3475.3149257689975,
#         "mean": 40.27146966857461,
#         "std": 249.40155994732868
#     },
#     "flow_latency_hvnet_p99.999": {
#         "min": 96.91391431999321,
#         "max": 1643777.9822396105,
#         "mean": 10436.833911201162,
#         "std": 96416.20166011255
#     },
#     "flow_latency_omnet_p99.999": {
#         "min": 5.7170667323799425,
#         "max": 3483.6790534090496,
#         "mean": 43.41103602438036,
#         "std": 249.77900530735812
#     },
#     "flow_latency_hvnet_p99.9999": {
#         "min": 97.90309143199498,
#         "max": 1644519.4809218731,
#         "mean": 11585.366077169203,
#         "std": 105206.98135574425
#     },
#     "flow_latency_omnet_p99.9999": {
#         "min": 5.725429773237909,
#         "max": 3495.018997717543,
#         "mean": 45.25038909516328,
#         "std": 250.12611042245325
#     }
# }
